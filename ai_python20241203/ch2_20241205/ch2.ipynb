# %%
"""
多註解
"""
x = 10#變數
y = 20
msg = 'Hello!!'
print(x)
print(y)
print(msg)
print(type(msg))
# Out:
# 10
# 20
# Hello!!
# <class 'str'>

# %%
x = 7.25 #類型變成float
y = "Howard"
msg = 62

print(x)
print(y)
print(msg)
# Out:
# 7.25
# Howard
# 62

# %% [markdown]
# ## 基本運算

# %%
a = 10
b = 3
c = a + b
print(c)
c = a - b
print(c)
c = a * b
print(c)
c = a / b
print(c)
#無條件捨去
c = a // b
print(c)
c = a % b#餘數
print(c)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1

# %%
a = 10
b = 2
訊息 = "你好"
print(a,b,訊息)
# Out:
# 10 2 你好

# %%
v1,v2,v3 = 2.5,36,"Ken"
print(v1,v2,v3)
print(type(v3))
# Out:
# 2.5 36 Ken
# <class 'str'>

# %% [markdown]
# ## 交換變數

# %%
x1 = 20
x2 = 30
x3 = x1
x1 = x2
x2 = x3
print("x1 =",x1,"x2 =",x2)
# Out:
# x1 = 30 x2 = 20

# %% [markdown]
# ## 考古題網站
# https://www.examtopics.com/exams/microsoft/ai-900/view/1/

# %% [markdown]
# ## Python專用交換

# %%
x1 = 20
x2 = 30
print("x1 =",x1,"x2 =",x2)
x1,x2 = x2,x1
print("x1 =",x1,"x2 =",x2)
# Out:
# x1 = 20 x2 = 30
# x1 = 30 x2 = 20

# %%
st1 = "你的"
st2 = "年齡是"
age = 18
print(st1,st2)
#合併字串
st3 = st1 + st2
print(st3)
#字串只能和字串合併
#st4 = st3 + age
#print(st4)
#str(age)把age轉字串
st5 =  st3 + str(age)
print(st5)
# Out:
# 你的 年齡是
# 你的年齡是
# 你的年齡是18

# %%
a,b = 10,3.1415
print("整數資料是:"+str(a))
print("浮點數是:"+str(b))
# Out:
# 整數資料是:10
# 浮點數是:3.1415

# %% [markdown]
# ## 輸入資料
# ### input("可放提示詞")
#
# 輸入的資料一律都是字串類型

# %%
a = input("請輸入一個數字")
print("您輸入的數字:",a)
ans = a * 3
print("ans:",ans)
# Out:
# 請輸入一個數字 5
# 您輸入的數字: 5
# ans: 555

# %%
print("y"*6)
# Out:
# yyyyyy

# %%
#int 轉整數 float 轉浮點數 str 轉字串
b = input("輸入一個數字")
ans = int(b) * 3
print("ans:",ans)
# Out:
# 輸入一個數字 5
# ans: 15

# %% [markdown]
# ## 變數計算2

# %%
x1 = 2
n = 2
ans = x1 ** n #x1的n次方 
print(ans)
# Out:
# 4

# %%
ans = 2 + 5 * 3
print(ans)
# Out:
# 17

# %%
ans = 2 ** 2 + 5 * 3**2
#      4     +  5  *  9
#      4     +   45
print(ans)
# Out:
# 49

# %% [markdown]
# ## 累計運算

# %%
count = 0
print("count:",count)
count = count + 1
print("count:",count)
count += 10
print("count:",count)
count -=  2
print("count:",count)
# Out:
# 請輸入數字 5
# count: 5
# count: 6
# count: 16
# count: 14

# %% [markdown]
# ![image.png](attachment:16c15064-4adb-4eed-afc9-628429ba8eea.png)

# %%
#大於75表示好
score = input("輸入成績")
print(type(score))
score = int(score)
print(score > 75)
# Out:
# 輸入成績 76
# <class 'str'>
# True

# %%
a1 = 10
a2 = 5
m1 = a1 > a2
print(m1)
print(a1 < a2)
print(a1 == a2)#等於
print(a1 != a2)#不等於
print(a1 >= a2)#包含a1
print(a1 <= a2)#包含a1
# Out:
# True
# False
# False
# True
# True
# False
